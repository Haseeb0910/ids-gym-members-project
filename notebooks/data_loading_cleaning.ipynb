# %%
import pandas as pd
import numpy as np

# %%
file_path = "../data/gym_members_exercise_tracking.csv"

df = pd.read_csv(file_path)
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.isna().sum()
